# %% [markdown]
# # ERD

# %% [markdown]
# ![png](sakila-db-model.png)

# %% [markdown]
# # SQL Queries

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

pymysql.install_as_MySQLdb()

# %%
connection = "mysql+pymysql://root:Hannah#0103@localhost/sakila"

# %%
engine = create_engine(connection)

# %%
connection
# Out:
# 'mysql+pymysql://root:Hannah#0103@localhost/sakila'

# %% [markdown]
# ## All Customers inside city_id 312

# %%
q1 = """SELECT c.first_name, c.last_name, c.email, a.address, cit.city
        FROM customer AS c
        JOIN address AS a ON c.customer_id = a.city_id
        JOIN city AS cit ON a.city_id = cit.city_id
        WHERE cit.city_id = 312"""

pd.read_sql(q1, engine)
# Out:
#   first_name last_name                             email             address  \
# 0       MARK  RINEHART  MARK.RINEHART@sakilacustomer.org   1497 Yuzhou Drive
# 1       MARK  RINEHART  MARK.RINEHART@sakilacustomer.org  548 Uruapan Street
#
#      city
# 0  London
# 1  London

# %% [markdown]
# ## All comdey films

# %%
q2 = """SELECT f.title, f.description, f.release_year, f.rating, f.special_features
        FROM film AS f
        JOIN film_category AS fc ON f.film_id = fc.category_id
        JOIN category AS c  ON fc.category_id = c.category_id
        WHERE c.name = 'Comedy'
    """

pd.read_sql(q2, engine)
# Out:
#           title                                        description  \
# 0   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 1   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 2   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 3   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 4   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 5   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 6   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 7   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 8   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 9   AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 10  AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 11  AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# 12  AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
# ...

# %% [markdown]
# ## All films with Johnny Lollobrigida

# %%
q3 = """SELECT f.title, f.release_year, a.first_name, a.last_name
        FROM film AS f
        JOIN film_actor AS fa ON f.film_id = fa.actor_id
        JOIN actor AS a ON fa.actor_id = a.actor_id
        WHERE a.first_name = 'Johnny' AND a.last_name = 'Lollobrigida'"""

pd.read_sql(q3, engine)
# Out:
#           title  release_year first_name     last_name
# 0   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 1   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 2   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 3   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 4   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 5   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 6   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 7   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 8   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 9   AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 10  AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 11  AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 12  AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 13  AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 14  AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# 15  AFRICAN EGG          2006     JOHNNY  LOLLOBRIGIDA
# ...

# %% [markdown]
# ## Actors in movie "Bingo Talented"

# %%
q4 = """SELECT a.first_name, a.last_name
        FROM actor AS a
        JOIN film_actor AS fa ON a.actor_id = fa.actor_id
        WHERE fa.film_id = (SELECT film_id 
                            FROM film
                            WHERE film.title = 'Bingo Talented');"""

pd.read_sql(q4, engine)
# Out:
#   first_name    last_name
# 0     GOLDIE        BRODY
# 1    CAMERON         WRAY
# 2       CARY  MCCONAUGHEY
# 3        JON        CHASE
# 4      RENEE         BALL

# %% [markdown]
# ## Customers with payments greater than 2 times the average payment

# %%
q5 = """SELECT customer_id, amount
        FROM payment
        WHERE amount >
            (SELECT 2*AVG(amount)
             FROM payment)
        ORDER BY amount ASC"""

pd.read_sql(q5, engine)
# Out:
#      customer_id  amount
# 0             75    8.97
# 1              3    8.99
# 2              3    8.99
# 3              3    8.99
# 4              4    8.99
# ..           ...     ...
# 852          237   11.99
# 853          305   11.99
# 854          362   11.99
# 855          591   11.99
# 856          592   11.99
#
# [857 rows x 2 columns]

# %% [markdown]
# ## First 5 customers with the highest amount of payments

# %%
q6 = """SELECT c.first_name, c.last_name,
            (SELECT COUNT(*)
             FROM payment
             WHERE c.customer_id = payment.customer_id) AS num_payments
        FROM customer AS c
        ORDER BY num_payments DESC
        LIMIT 5;
"""

pd.read_sql(q6, engine)
# Out:
#   first_name last_name  num_payments
# 0    ELEANOR      HUNT            46
# 1       KARL      SEAL            45
# 2     MARCIA      DEAN            42
# 3      CLARA      SHAW            42
# 4      TAMMY   SANDERS            41
